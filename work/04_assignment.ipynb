# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.

# %%
import pandas as pd

# %%
filepath = '../data/billionaire.csv'
data = pd.read_csv(filepath)

# %%
filepath = '../data/billionaire.csv'
data = pd.read_csv(filepath)
name = data['Name']
country = data['Country']
industry = data['Industry']
d = {"Name": name, "Country": country, "Industry": industry}
df = pd.DataFrame(d)
df['Industry'].mode()
# Out:
# 0    Finance & Investments
# dtype: object

# %%
df['Industry'].value_counts()
# Out:
# Finance & Investments         371
# Technology                    365
# Manufacturing                 331
# Fashion & Retail              273
# Healthcare                    221
# Food & Beverage               219
# Real Estate                   215
# Diversified                   188
# Energy                        100
# Media & Entertainment          95
# Service                        75
# Metals & Mining                74
# Automotive                     68
# Construction & Engineering     44
# Logistics                      35
# Telecom                        32
# Gambling & Casinos             25
# Sports                         24
# Name: Industry, dtype: int64

# %%
import matplotlib.pyplot as plt
name = ['Finanace & Investment', 'Technology', 'Manufacturing', 'Fashion & Retail', 'Healthcare']
people = [371, 365, 331, 273, 221]
p1= plt.pie(people, labels=name, autopct='%0.f%%', shadow=True, startangle=90)
plt.title("Most Popular Industries for Billionaires");
plt.legend(['Finance & Investment', 'Technology','Manufacturing','Fashion & Retail','Healthcare'],bbox_to_anchor=(1.2,1.03),loc="upper left");
plt.axis('equal');
plt.savefig('hall.pdf', bbox_inches='tight')

# %% [markdown]
# 5: This plot shows the top five most popular industries for the Forbes Billionaire List 2021.
# 6: I have already created a pie chart for the top ten most successful billionaires' industries and I wanted to show the most common overall. I chose a pie chart because it allows for a simple visual to see what is most common industries with percentagages. It also only shows the top five most common industries overall because there are so many I thought this would be an easier visual to understand when presenting. Lastly, I think a pie chart makes the most sense because they are individual industries and a line graph or scatter plot would not make sense. I also thought about a bar graph, but I thought a pie chart would be more visually pleasing.
